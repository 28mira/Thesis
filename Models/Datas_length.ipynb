# %%
import pandas as pd
import os
import cv2
import csv
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
import h5py
from torchvision import transforms
import tensorflow as tf
from tensorflow.keras import models, layers, preprocessing, datasets

# %%
input_folder = r'C:\Users\marto\Desktop\Szakdolgozat\pogram\brainTumor\Astrocytoma_Ganglioglioma'
db = 0
for file_name in sorted(os.listdir(input_folder)):
        if file_name.endswith('.jpg'):
            file_path = os.path.join(input_folder,file_name)
            db+=1
print(db)
# Out:
# 38

# %%
input_folder = r'C:\Users\marto\Desktop\Szakdolgozat\pogram\brainTumor\converted_data'
db = 0
for file_name in sorted(os.listdir(input_folder)):
        if file_name.endswith('.jpg'):
            file_path = os.path.join(input_folder,file_name)
            db+=1
print(db)
# Out:
# 3064

# %%
input_folder = r'C:\Users\marto\Desktop\Szakdolgozat\pogram\brainTumor\demyelinating_lesions'
db = 0
for file_name in sorted(os.listdir(input_folder)):
        if file_name.endswith('.jpg'):
            file_path = os.path.join(input_folder,file_name)
            db+=1
print(db)
# Out:
# 38

# %%
input_folder = r'C:\Users\marto\Desktop\Szakdolgozat\pogram\brainTumor\Dermoid'
db = 0
for file_name in sorted(os.listdir(input_folder)):
        if file_name.endswith('.jpg'):
            file_path = os.path.join(input_folder,file_name)
            db+=1
print(db)
# Out:
# 38

# %%
input_folder = r'C:\Users\marto\Desktop\Szakdolgozat\pogram\brainTumor\Ependymoma'
db = 0
for file_name in sorted(os.listdir(input_folder)):
        if file_name.endswith('.jpg'):
            file_path = os.path.join(input_folder,file_name)
            db+=1
print(db)
# Out:
# 36

# %%
input_folder = r'C:\Users\marto\Desktop\Szakdolgozat\pogram\brainTumor\Glioma'
db = 0
for file_name in sorted(os.listdir(input_folder)):
        if file_name.endswith('.jpg'):
            file_path = os.path.join(input_folder,file_name)
            db+=1
print(db)
# Out:
# 76

# %%
input_folder = r'C:\Users\marto\Desktop\Szakdolgozat\pogram\brainTumor\Hemangioblastoma_Pleomorphic'
db = 0
for file_name in sorted(os.listdir(input_folder)):
        if file_name.endswith('.jpg'):
            file_path = os.path.join(input_folder,file_name)
            db+=1
print(db)
# Out:
# 74

# %%
input_folder = r'C:\Users\marto\Desktop\Szakdolgozat\pogram\brainTumor\Hemorrhagic'
db = 0
for file_name in sorted(os.listdir(input_folder)):
        if file_name.endswith('.jpg'):
            file_path = os.path.join(input_folder,file_name)
            db+=1
print(db)
# Out:
# 38

# %%
input_folder = r'C:\Users\marto\Desktop\Szakdolgozat\pogram\brainTumor\Malformation'
db = 0
for file_name in sorted(os.listdir(input_folder)):
        if file_name.endswith('.jpg'):
            file_path = os.path.join(input_folder,file_name)
            db+=1
print(db)
# Out:
# 38

# %%
input_folder = r'C:\Users\marto\Desktop\Szakdolgozat\pogram\brainTumor\meningioma'
db = 0
for file_name in sorted(os.listdir(input_folder)):
        if file_name.endswith('.jpg'):
            file_path = os.path.join(input_folder,file_name)
            db+=1
print(db)
# Out:
# 76

# %%
input_folder = r'C:\Users\marto\Desktop\Szakdolgozat\pogram\brainTumor\Normal'
db = 0
for file_name in sorted(os.listdir(input_folder)):
        if file_name.endswith('.jpg'):
            file_path = os.path.join(input_folder,file_name)
            db+=1
print(db)
# Out:
# 1749

# %%
input_folder = r'C:\Users\marto\Desktop\Szakdolgozat\pogram\brainTumor\Recurrenceremnant'
db = 0
for file_name in sorted(os.listdir(input_folder)):
        if file_name.endswith('.jpg'):
            file_path = os.path.join(input_folder,file_name)
            db+=1
print(db)
# Out:
# 114

# %%
input_folder = r'C:\Users\marto\Desktop\Szakdolgozat\pogram\brainTumor\Stroke_Demyelination'
db = 0
for file_name in sorted(os.listdir(input_folder)):
        if file_name.endswith('.jpg'):
            file_path = os.path.join(input_folder,file_name)
            db+=1
print(db)
# Out:
# 38

# %%
input_folder = r'C:\Users\marto\Desktop\Szakdolgozat\pogram\brainTumor\Stroke_Haemorrhage'
db = 0
for file_name in sorted(os.listdir(input_folder)):
        if file_name.endswith('.jpg'):
            file_path = os.path.join(input_folder,file_name)
            db+=1
print(db)
# Out:
# 564

# %%
input_folder = r'C:\Users\marto\Desktop\Szakdolgozat\pogram\brainTumor\Stroke_infarct'
db = 0
for file_name in sorted(os.listdir(input_folder)):
        if file_name.endswith('.jpg'):
            file_path = os.path.join(input_folder,file_name)
            db+=1
print(db)
# Out:
# 906

# %%
input_folder = r'C:\Users\marto\Desktop\Szakdolgozat\pogram\brainTumor\White_Matter_Disease'
db = 0
for file_name in sorted(os.listdir(input_folder)):
        if file_name.endswith('.jpg'):
            file_path = os.path.join(input_folder,file_name)
            db+=1
print(db)
# Out:
# 36
